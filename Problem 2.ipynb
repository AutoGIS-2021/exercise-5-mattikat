# %%
from pyproj import crs
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

data_fp = r'data/hsl_pysäkit_määrät.shp'   #URl:https://hri.fi/data/dataset/hsl-n-nousijamaarat-pysakeittain
data = gpd.read_file(data_fp)
epsg_number =str(m.crs[4:])
if data.crs != m.crs:
    data = data.to_crs(epsg=epsg_number)

# %%
# Taking 100 most used public transport stops
data = data.nlargest(100,'Nousijamaa')

# %%
points_gjson = folium.features.GeoJson(data['geometry'], name='Public Transport Stations')

# %%
import mapclassify
#mapclassify.NaturalBreaks(y=data['Nousijamaa'],k=10)
classifier = mapclassify.NaturalBreaks.make(k=10)
classifier
data['class'] = data[['Nousijamaa']].apply(classifier)

# %%
from folium.plugins import MarkerCluster
m = folium.Map(location=[60.25,25.0],
               zoom_start=11,
               tiles='CartoDBpositron'
              )

points = list(zip(data['geometry'].y,data['geometry'].x))
marker_cluster = MarkerCluster(locations=points, name='100 most used public trasnport stops/stations')
marker_cluster.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.features.GeoJson(data,  
                        name='Labels',
                        style_function=lambda x: {'color':'Red','weight':0},
                        tooltip=folium.features.GeoJsonTooltip(fields=['Nousijamaa'],
                                                                aliases = ['Commuters'],
                                                                labels=True,
                                                                sticky=True
                                                                            )
                       ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.LayerControl().add_to(m)
m
# 100 ruuhkaisinta pysäkkiä, cluster point map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
